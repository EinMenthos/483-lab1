# %% [markdown]
# ## <b>Understanding Feedforward Neural Network</b>

# %% [markdown]
# In this lab, you are required to build 3 Feedforward Neural Networks to simulate function
# <br> $y = xsin( \frac {x^2} {300})$
# <br> in range x: +-100
# <br> You need to have a different structure for each model you build.

# %% [markdown]
# ##Requirements

# %% [markdown]
# 1 You are required to finish each part below following instructions.
# <br>2 You may work on native py files, but your work needs to include same documentation. You may use pytorch or tensorflow keras.
# <br>3 You may work in a group of 2.
#
# <br><b>For submission, submit a link to your github repo</b>
# <br>Each student in the group must all submit.

# %% [markdown]
# #### Part 1 data preparation
#
# In the cell below, generate training data for your model.
# <br> Generate a decent amount of training data in the interval of x.
# <br>
# <br>All data need to be separated by the same distance.

# %%
import numpy as np

def func(xc):
    return xc * np.sin((xc**2)/300)
#    return xc**3 - 50*xc**2 - 500*xc + 1000
#    return xc ** 2

#this is the range and the samples I want
xc = np.linspace(-100, 100, 10000)
yc = func(xc)

training_data = np.column_stack((xc, yc))
print(training_data[:10000])
# Out:
# [[-100.          -94.05295766]
#  [ -99.979998    -94.47863179]
#  [ -99.959996    -94.88725161]
#  ...
#  [  99.959996     94.88725161]
#  [  99.979998     94.47863179]
#  [ 100.           94.05295766]]

# %% [markdown]
# #### Part 2 build models
#
# In the cells below, build your models and train it with data from part1.
# <br>You need to split your training data to two parts. With 40% used in training, and 60% used in test.
#
# <br>You may do this with sklearn's train_test_split() or keras' validation_split together with train_test_split().

# %%
#model1
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, Activation, Flatten
from sklearn.model_selection import train_test_split

# Split data into train and test sets
x_train1, x_test1, y_train1, y_test1 = train_test_split(xc, yc, test_size=0.6, random_state=42)

#define model
model1 = Sequential()
model1.add(Input(shape=(1,)))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(1))

#compile model
model1.compile(
   loss = 'MAE', optimizer = 'Adam', metrics=['mae']
)
#model.fit(X_train, Y_train, batch_size = 128, epochs = 50)
model1.fit(x_train1, y_train1, epochs=50, batch_size=128, validation_data=(x_test1, y_test1))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 6ms/step - loss: 31.7233 - mae: 31.7233 - val_loss: 32.0832 - val_mae: 32.0832
# Epoch 2/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.6671 - mae: 31.6671 - val_loss: 32.0501 - val_mae: 32.0501
# Epoch 3/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.6320 - mae: 31.6320 - val_loss: 32.0065 - val_mae: 32.0065
# Epoch 4/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.5995 - mae: 31.5995 - val_loss: 31.9140 - val_mae: 31.9140
# Epoch 5/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.5466 - mae: 31.5466 - val_loss: 31.8899 - val_mae: 31.8899
# Epoch 6/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.4316 - mae: 31.4316 - val_loss: 31.6928 - val_mae: 31.6928
# Epoch 7/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.2399 - mae: 31.2399 - val_loss: 31.5254 - val_mae: 31.5254
# Epoch 8/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.0982 - mae: 31.0982 - val_loss: 31.3032 - val_mae: 31.3032
# Epoch 9/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.4081 - mae: 30.4081 - val_loss: 30.3251 - val_mae: 30.3251
# Epoch 10/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.8547 - mae: 30.8547 - val_loss: 30.9052 - val_mae: 30.9052
# Epoch 11/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.3808 - mae: 30.3808 - val_loss: 30.7898 - val_mae: 30.7898
# Epoch 12/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.0800 - mae: 30.0800 - val_loss: 31.1041 - val_mae: 31.1041
# Epoch 13/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.9706 - mae: 29.9706 - val_loss: 30.7800 - val_mae: 30.7800
# Epoch 14/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.7008 - mae: 29.7008 - val_loss: 30.3031 - val_mae: 30.3031
# Epoch 15/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.5737 - mae: 29.5737 - val_loss: 30.0164 - val_mae: 30.0164
# Epoch 16/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.2934 - mae: 29.2934 - val_loss: 28.8260 - val_mae: 28.8260
# Epoch 17/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.5779 - mae: 28.5779 - val_loss: 28.3947 - val_mae: 28.3947
# Epoch 18/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.1631 - mae: 28.1631 - val_loss: 29.5265 - val_mae: 29.5265
# Epoch 19/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.0839 - mae: 29.0839 - val_loss: 29.5525 - val_mae: 29.5525
# Epoch 20/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.3468 - mae: 28.3468 - val_loss: 28.2158 - val_mae: 28.2158
# Epoch 21/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.4484 - mae: 27.4484 - val_loss: 28.0412 - val_mae: 28.0412
# Epoch 22/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.5194 - mae: 27.5194 - val_loss: 27.1648 - val_mae: 27.1648
# Epoch 23/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.5670 - mae: 27.5670 - val_loss: 27.8411 - val_mae: 27.8411
# Epoch 24/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.5149 - mae: 26.5149 - val_loss: 27.2721 - val_mae: 27.2721
# Epoch 25/50
# 32/32 [==============================] - 0s 5ms/step - loss: 26.8945 - mae: 26.8945 - val_loss: 28.6616 - val_mae: 28.6616
# Epoch 26/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.1077 - mae: 27.1077 - val_loss: 25.7936 - val_mae: 25.7936
# Epoch 27/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.0356 - mae: 27.0356 - val_loss: 28.1264 - val_mae: 28.1264
# Epoch 28/50
# 32/32 [==============================] - 0s 5ms/step - loss: 26.2187 - mae: 26.2187 - val_loss: 29.2040 - val_mae: 29.2040
# Epoch 29/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27
# 32/32 [==============================] - 0s 4ms/step - loss: 24.7957 - mae: 24.7957 - val_loss: 25.5869 - val_mae: 25.5869

# %%
#model2 - trying LeakyReLU to avoid dead neurons
#from tensorflow import keras
#from keras import layers
#from keras.models import Sequential
#from keras.layers import Input, Dense, Dropout, Activation, Flatten
#from sklearn.model_selection import train_test_split

# Split data into train and test sets
x_train2, x_test2, y_train2, y_test2 = train_test_split(xc, yc, test_size=0.6, random_state=42)

#define model
model2 = Sequential()
model2.add(Input(shape=(1,)))
#forced alpha = 0.01
#model2.add(Dense(150,activation = keras.layers.LeakyReLU(alpha=0.01)))
#model2.add(Dense(150,activation = keras.layers.LeakyReLU(alpha=0.01)))
#model2.add(Dense(150,activation = keras.layers.LeakyReLU(alpha=0.01)))
#using default value: 0.3
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(1))

#compile model
model2.compile(
   loss = 'MAE', optimizer = 'Adam', metrics=['mae']
)
#model.fit(X_train, Y_train, batch_size = 128, epochs = 50)
model2.fit(x_train2, y_train2, epochs=50, batch_size=128, validation_data=(x_test2, y_test2))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 1s 6ms/step - loss: 31.7750 - mae: 31.7750 - val_loss: 32.1045 - val_mae: 32.1045
# Epoch 2/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.6767 - mae: 31.6767 - val_loss: 32.1225 - val_mae: 32.1225
# Epoch 3/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.6567 - mae: 31.6567 - val_loss: 32.0273 - val_mae: 32.0273
# Epoch 4/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.7174 - mae: 31.7174 - val_loss: 32.0936 - val_mae: 32.0936
# Epoch 5/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.7428 - mae: 31.7428 - val_loss: 32.0316 - val_mae: 32.0316
# Epoch 6/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.6741 - mae: 31.6741 - val_loss: 31.9579 - val_mae: 31.9579
# Epoch 7/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.6064 - mae: 31.6064 - val_loss: 31.9612 - val_mae: 31.9612
# Epoch 8/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.4761 - mae: 31.4761 - val_loss: 31.9190 - val_mae: 31.9190
# Epoch 9/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.4885 - mae: 31.4885 - val_loss: 31.8308 - val_mae: 31.8308
# Epoch 10/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.3144 - mae: 31.3144 - val_loss: 31.4673 - val_mae: 31.4673
# Epoch 11/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.8742 - mae: 30.8742 - val_loss: 30.8907 - val_mae: 30.8907
# Epoch 12/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.4140 - mae: 30.4140 - val_loss: 31.2325 - val_mae: 31.2325
# Epoch 13/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.3709 - mae: 30.3709 - val_loss: 30.3868 - val_mae: 30.3868
# Epoch 14/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.7082 - mae: 29.7082 - val_loss: 29.9466 - val_mae: 29.9466
# Epoch 15/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.8350 - mae: 29.8350 - val_loss: 30.5443 - val_mae: 30.5443
# Epoch 16/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.4274 - mae: 29.4274 - val_loss: 30.1905 - val_mae: 30.1905
# Epoch 17/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.3918 - mae: 29.3918 - val_loss: 29.7618 - val_mae: 29.7618
# Epoch 18/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.0733 - mae: 29.0733 - val_loss: 29.6287 - val_mae: 29.6287
# Epoch 19/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.3799 - mae: 29.3799 - val_loss: 29.6491 - val_mae: 29.6491
# Epoch 20/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.1081 - mae: 29.1081 - val_loss: 28.8993 - val_mae: 28.8993
# Epoch 21/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.6798 - mae: 28.6798 - val_loss: 29.4013 - val_mae: 29.4013
# Epoch 22/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.1003 - mae: 29.1003 - val_loss: 29.6499 - val_mae: 29.6499
# Epoch 23/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.9709 - mae: 28.9709 - val_loss: 31.1739 - val_mae: 31.1739
# Epoch 24/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.2392 - mae: 29.2392 - val_loss: 28.5891 - val_mae: 28.5891
# Epoch 25/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.3491 - mae: 28.3491 - val_loss: 28.2510 - val_mae: 28.2510
# Epoch 26/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.3107 - mae: 28.3107 - val_loss: 28.8763 - val_mae: 28.8763
# Epoch 27/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.1003 - mae: 28.1003 - val_loss: 29.2566 - val_mae: 29.2566
# Epoch 28/50
# 32/32 [==============================] - 0s 6ms/step - loss: 28.6983 - mae: 28.6983 - val_loss: 28.6147 - val_mae: 28.6147
# Epoch 29/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.5558 - mae: 27.5558 - val_loss: 28.2033 - val_mae: 28.2033
# Epoch 30/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.0124 - mae: 28.0124 - val_loss: 28.1593 - val_mae: 28.1593
# Epoch 31/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.5612 - mae: 27.5612 - val_loss: 27.7714 - val_mae: 27.7714
# Epoch 32/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.7909 - mae: 27.7909 - val_loss: 28.2770 - val_mae: 28.2770
# Epoch 33/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.3270 - mae: 28.3270 - val_loss: 28.3800 - val_mae: 28.3800
# Epoch 34/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.5937 - mae: 27.5937 - val_loss: 28.0661 - val_mae: 28.0661
# Epoch 35/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.5066 - mae: 27.5066 - val_loss: 28.5952 - val_mae: 28.5952
# Epoch 36/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.9019 - mae: 27.9019 - val_loss: 28.2695 - val_mae: 28.2695
# Epoch 37/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.1875 - mae: 27.1875 - val_loss: 29.1569 - val_mae: 29.1569
# Epoch 38/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.2663 - mae: 27.2663 - val_loss: 27.4948 - val_mae: 27.4948
# Epoch 39/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.2165 - mae: 27.2165 - val_loss: 28.5252 - val_mae: 28.5252
# Epoch 40/50
# 32/32 [==============================] - 0s 5ms/step - loss: 26.7261 - mae: 26.7261 - val_loss: 26.6861 - val_mae: 26.6861
# Epoch 41/50
# 32/32 [==============================] - 0s 5ms/step - loss: 27.1620 - mae: 27.1620 - val_loss: 29.9186 - val_mae: 29.9186
# Epoch 42/50
# 32/32 [==============================] - 0s 5ms/step - loss: 26.7665 - mae: 26.7665 - val_loss: 26.5549 - val_mae: 26.5549
# Epoch 43/50
# 32/32 [==============================] - 0s 6ms/step - loss: 26.6090 - mae: 26.6090 - val_loss: 29.5668 - val_mae: 29.5668
# Epoch 44/50
# 32/32 [==============================] - 0s 7ms/step - loss: 27.0606 - mae: 27.0606 - val_loss: 27.5107 - val_mae: 27.5107
# Epoch 45/50
# 32/32 [==============================] - 0s 6ms/step - loss: 26.6584 - mae: 26.6584 - val_loss: 26.8039 - val_mae: 26.8039
# Epoch 46/50
# 32/32 [==============================] - 0s 6ms/step - loss: 26.9806 - mae: 26.9806 - val_loss: 27.7285 - val_mae: 27.7285
# Epoch 47/50
# 32/32 [==============================] - 0s 6ms/step - loss: 26.8407 - mae: 26.8407 - val_loss: 25.8418 - val_mae: 25.8418
# Epoch 48/50
# 32/32 [==============================] - 0s 5ms/step - loss: 26.0335 - mae: 26.0335 - val_loss: 26.4787 - val_mae: 26.4787
# Epoch 49/50
# 32/32 [==============================] - 0s 5ms/step - loss: 25.4061 - mae: 25.4061 - val_loss: 26.7229 - val_mae: 26.7229
# Epoch 50/50
# 32/32 [==============================] - 0s 5ms/step - loss: 25.8685 - mae: 25.8685 - val_loss: 24.9142 - val_mae: 24.9142

# %%
#model3 - trying PReLU due to varying characteristics and signal propagation
#from tensorflow import keras
#from keras import layers
#from keras.models import Sequential
#from keras.layers import Input, Dense, Dropout, Activation, Flatten
#from sklearn.model_selection import train_test_split

# Split data into train and test sets
x_train3, x_test3, y_train3, y_test3 = train_test_split(xc, yc, test_size=0.6, random_state=42)

#define model
model3 = Sequential()
model3.add(Input(shape=(1,)))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(1))

#compile model
model3.compile(
   loss = 'MAE', optimizer = 'Adam', metrics=['mae']
)
#model.fit(X_train, Y_train, batch_size = 128, epochs = 50)
model3.fit(x_train3, y_train3, epochs=50, batch_size=128, validation_data=(x_test3, y_test3))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 7ms/step - loss: 31.4196 - mae: 31.4196 - val_loss: 31.5662 - val_mae: 31.5662
# Epoch 2/50
# 32/32 [==============================] - 0s 4ms/step - loss: 30.8516 - mae: 30.8516 - val_loss: 31.1222 - val_mae: 31.1222
# Epoch 3/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.0613 - mae: 30.0613 - val_loss: 30.7064 - val_mae: 30.7064
# Epoch 4/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29
# Epoch 45/50
# 32/32 [==============================] - 0s 6ms/step - loss: 20.7888 - mae: 20.7888 - val_loss: 20.6426 - val_mae: 20.6426
# Epoch 46/50
# 32/32 [==============================] - 0s 6ms/step - loss: 20.6514 - mae: 20.6514 - val_loss: 20.6072 - val_mae: 20.6072
# Epoch 47/50
# 32/32 [==============================] - 0s 6ms/step - loss: 19.3708 - mae: 19.3708 - val_loss: 19.8529 - val_mae: 19.8529
# Epoch 48/50
# 32/32 [==============================] - 0s 6ms/step - loss: 20.2216 - mae: 20.2216 - val_loss: 19.1825 - val_mae: 19.1825
# Epoch 49/50
# 32/32 [==============================] - 0s 6ms/step - loss: 18.8073 - mae: 18.8073 - val_loss: 18.5160 - val_mae: 18.5160
# Epoch 50/50
# 32/32 [==============================] - 0s 6ms/step - loss: 19.3091 - mae: 19.3091 - val_loss: 19.5950 - val_mae: 19.5950

# %% [markdown]
# #### Part 3 model evaluation
#
# In the cells below, eval your model with training data, test data ( with model.evaluate( ) ), and plot your predict result on the same plot with the plot of goal function.

# %%
import matplotlib.pyplot as plt

# Evaluate the model1 on training data
train_loss1 = model1.evaluate(x_train1, y_train1)
print("Training Loss1:", train_loss1)

# Evaluate the model on test data
#loss1, accuracy1 = model1.evaluate(x_test1, y_test1)
test_loss1 = model1.evaluate(x_test1, y_test1)
print("Test Loss1:", test_loss1)

py1 = model1.predict(xc)

plt.plot(xc, py1)
plt.plot(xc, yc)
plt.title("Model1 Fit")
plt.show()
#es = []
#for i in range(len(py)):
#  es.append(yc[i] - py[i])
#plt.plot(xc, es)
#plt.title("Error")
#plt.show()

# Evaluate the model2 on training data
train_loss2 = model2.evaluate(x_train2, y_train2)
print("Training Loss2:", train_loss2)

# Evaluate the model on test data
test_loss2 = model2.evaluate(x_test2, y_test2)
print("Test Loss2:", test_loss2)

py2 = model2.predict(xc)

plt.plot(xc, py2)
plt.plot(xc, yc)
plt.title("Model2 Fit")
plt.show()

# Evaluate the model3 on training data
train_loss3 = model3.evaluate(x_train3, y_train3)
print("Training Loss3:", train_loss3)

# Evaluate the model on test data
test_loss3 = model3.evaluate(x_test3, y_test3)
print("Test Loss3:", test_loss3)

py3 = model3.predict(xc)

plt.plot(xc, py3)
plt.plot(xc, yc)
plt.title("Model3 Fit")
plt.show()
# Out:
# 125/125 [==============================] - 0s 539us/step - loss: 25.0739 - mae: 25.0739
# Training Loss1: [25.073909759521484, 25.073909759521484]
# 188/188 [==============================] - 0s 521us/step - loss: 25.5869 - mae: 25.5869
# Test Loss1: [25.586891174316406, 25.586891174316406]
# 313/313 [==============================] - 0s 502us/step
# 125/125 [==============================] - 0s 565us/step - loss: 24.4251 - mae: 24.4251
# Training Loss2: [24.425121307373047, 24.425121307373047]
# 188/188 [==============================] - 0s 542us/step - loss: 24.9142 - mae: 24.9142
# Test Loss2: [24.914220809936523, 24.914220809936523]
# 313/313 [==============================] - 0s 506us/step
# 125/125 [==============================] - 0s 1ms/step - loss: 18.9087 - mae: 18.9087
# Training Loss3: [18.908735275268555, 18.908735275268555]
# 188/188 [==============================] - 0s 757us/step - loss: 19.5950 - mae: 19.5950
# Test Loss3: [19.59497833251953, 19.59497833251953]
# 313/313 [==============================] - 0s 600us/step

# %% [markdown]
# #### Part 4 get model output and feedforward by yourself
#
# Recall how a Feedforward Neural Network gets its output. Now choose your model with highest accuracy, and call get_weights( ) to get its weights and bias.
# <br> Hint: bias and weights have different dimensions in most cases. Try to guess which index represent bias before you look it up on the internet.
#
# <br> Afterwards, choose 5 data from your training dataset, do all the necessary calculations (with program of course), and get the output of your model. Compare it to the model.predict( ) result.
# <br> They should be identical for the first several digitals, if not for all digits.

# %%
# to pick the model that has the highest accuracy, we need to choos the model with lowest loss.

# Get the model with the highest accuracy
best_model = model1  # Assume model1 has the highest accuracy initially
lowest_loss = test_loss1
print("model1 selected as best model")


#loss1, accuracy1 = model1.evaluate(x_test1, y_test1)
if test_loss2 < lowest_loss:
    lowest_loss = test_loss2
    best_model = model2
    print("model2 selected as best model")

if test_loss3 < lowest_loss:
    lowest_loss = test_loss3
    best_model = model3
    print("model3 selected as best model")


#best_model = model3
#best_accuracy = test_loss3[1]

# Get the weights and biases of the chosen model
weights = []
biases = []

for layer in best_model.layers:
    weights.append(layer.get_weights()[0])
    biases.append(layer.get_weights()[1])

# Choose 5 random data points from the training dataset
x_samples = x_train1[:5]
# Reshape x_samples to have dimensions (num_samples, num_features)
x_samples = np.reshape(x_samples, (x_samples.shape[0], 1))

# Compute the output of the model manually
for i, (w, b) in enumerate(zip(weights, biases)):
    x_samples = np.dot(x_samples, w) + b
    if i < len(weights) - 1:  # Apply activation function except for the last layer
        if (best_model == model1):
            #print("compute output model1 - RELU")
            x_samples = np.maximum(x_samples, 0)  # ReLU activation function
        if (best_model == model2):
            #print("compute output model2 - LEAKYRELU")
            #x_samples = np.maximum(0.01 * x_samples, x_samples) # LeakyReLU in forced mode
            #https://stackoverflow.com/questions/64735352/details-about-alpha-in-tf-nn-leaky-relu-features-alpha-0-2-name-none#:~:text=So%20Leaky%20ReLU%20substitutes%20zero,learning%20without%20reaching%20dead%20end.
            x_samples = np.maximum(0.3 * x_samples, x_samples) # LeakyReLU using default values
            
        if (best_model == model3):
            #print("compute output model3 - ELU")
            #x_samples = np.maximum(x_samples, 0.25 * x_samples)  # ReLU activation function
            x_samples = np.where(x_samples >= 0, x_samples, 1 * (np.exp(x_samples) - 1))  # ELU activation function

# Get the output of the model using model.predict()
predicted_output = best_model.predict(x_train1[:5])

# Print the manually computed output and the output obtained from model.predict()
print("Manually Computed Output (weights and bias):")
print(x_samples)

print("\nOutput from model.predict():")
print(predicted_output)
# Out:
# model1 selected as best model
# model2 selected as best model
# model3 selected as best model
# 1/1 [==============================] - 0s 12ms/step
# Manually Computed Output (weights and bias):
# [[-37.70165589]
#  [  8.09287371]
#  [ 20.83672338]
#  [ 40.23659731]
#  [ 52.67578269]]
#
# Output from model.predict():
# [[-37.701675]
#  [  8.092875]
#  [ 20.836723]
#  [ 40.236607]
#  [ 52.675716]]
