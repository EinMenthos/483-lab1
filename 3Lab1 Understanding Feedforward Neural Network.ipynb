# %% [markdown]
# ## <b>Understanding Feedforward Neural Network</b>

# %% [markdown]
# In this lab, you are required to build 3 Feedforward Neural Networks to simulate function
# <br> $y = xsin( \frac {x^2} {300})$
# <br> in range x: +-100
# <br> You need to have a different structure for each model you build.

# %% [markdown]
# ##Requirements

# %% [markdown]
# 1 You are required to finish each part below following instructions.
# <br>2 You may work on native py files, but your work needs to include same documentation. You may use pytorch or tensorflow keras.
# <br>3 You may work in a group of 2.
#
# <br><b>For submission, submit a link to your github repo</b>
# <br>Each student in the group must all submit.

# %% [markdown]
# #### Part 1 data preparation
#
# In the cell below, generate training data for your model.
# <br> Generate a decent amount of training data in the interval of x.
# <br>
# <br>All data need to be separated by the same distance.

# %%
import numpy as np

def func(xc):
    return xc * np.sin((xc**2)/300)

#this is the range and the samples I want
xc = np.linspace(-100, 100, 10000)
yc = func(xc)

training_data = np.column_stack((xc, yc))
print(training_data[:10000])
# Out:
# [[-100.          -94.05295766]
#  [ -99.979998    -94.47863179]
#  [ -99.959996    -94.88725161]
#  ...
#  [  99.959996     94.88725161]
#  [  99.979998     94.47863179]
#  [ 100.           94.05295766]]

# %% [markdown]
# #### Part 2 build models
#
# In the cells below, build your models and train it with data from part1.
# <br>You need to split your training data to two parts. With 40% used in training, and 60% used in test.
#
# <br>You may do this with sklearn's train_test_split() or keras' validation_split together with train_test_split().

# %%
#model1
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, Activation, Flatten
from sklearn.model_selection import train_test_split

# Split data into train and test sets
x_train1, x_test1, y_train1, y_test1 = train_test_split(xc, yc, test_size=0.6, random_state=42)

#define model
model1 = Sequential()
model1.add(Input(shape=(1,)))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(150,activation = "relu"))
model1.add(Dense(1))

#compile model
model1.compile(
   loss = 'MAE', optimizer = 'Adam', metrics=['mae']
)
model1.fit(x_train1, y_train1, epochs=50, batch_size=128, validation_data=(x_test1, y_test1))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 6ms/step - loss: 31.7648 - mae: 31.7648 - val_loss: 32.1176 - val_mae: 32.1176
# Epoch 2/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.7299 - mae: 31.7299 - val_loss: 32.1233 - val_mae: 32.1233
# Epoch 3/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.6515 - mae: 31.6515 - val_loss: 32.0757 - val_mae: 32.0757
# Epoch 4/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.6432 - mae: 31.6432 - val_loss: 31.9729 - val_mae: 31.9729
# Epoch 5/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.5359 - mae: 31.5359 - val_loss: 31.9105 - val_mae: 31.9105
# Epoch 6/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.4284 - mae: 31.4284 - val_loss: 31.7678 - val_mae: 31.7678
# Epoch 7/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.3224 - mae: 31.3224 - val_loss: 31.5743 - val_mae: 31.5743
# Epoch 8/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.3763 - mae: 31.3763 - val_loss: 31.9669 - val_mae: 31.9669
# Epoch 9/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.5229 - mae: 31.5229 - val_loss: 31.7984 - val_mae: 31.7984
# Epoch 10/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.2340 - mae: 31.2340 - val_loss: 31.6192 - val_mae: 31.6192
# Epoch 11/50
# 32/32 [==============================] - 0s 4ms/step - loss: 30.9058 - mae: 30.9058 - val_loss: 30.8233 - val_mae: 30.8233
# Epoch 12/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.3396 - mae: 30.3396 - val_loss: 30.5801 - val_mae: 30.5801
# Epoch 13/50
# 32/32 [==============================] - 0s 4ms/step - loss: 29.7264 - mae: 29.7264 - val_loss: 29.6632 - val_mae: 29.6632
# Epoch 14/50
# 32/32 [==============================] - 0s 4ms/step - loss: 29.9915 - mae: 29.9915 - val_loss: 29.8035 - val_mae: 29.8035
# Epoch 15/50
# 32/32 [==============================] - 0s 4ms/step - loss: 29.1679 - mae: 29.1679 - val_loss: 29.6047 - val_mae: 29.6047
# Epoch 16/50
# 32/32 [==============================] - 0s 4ms/step - loss: 29.2482 - mae: 29.2482 - val_loss: 28.9371 - val_mae: 28.9371
# Epoch 17/50
# 32/32 [==============================] - 0s 4ms/step - loss: 28.7055 - mae: 28.7055 - val_loss: 28.9184 - val_mae: 28.9184
# Epoch 18/50
# 32/32 [==============================] - 0s 4ms/step - loss: 28.3645 - mae: 28.3645 - val_loss: 28.3643 - val_mae: 28.3643
# Epoch 19/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.8820 - mae: 28.8820 - val_loss: 29.2218 - val_mae: 29.2218
# Epoch 20/50
# 32/32 [==============================] - 0s 4ms/step - loss: 28.2055 - mae: 28.2055 - val_loss: 29.4642 - val_mae: 29.4642
# Epoch 21/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.8849 - mae: 27.8849 - val_loss: 27.5484 - val_mae: 27.5484
# Epoch 22/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.7589 - mae: 27.7589 - val_loss: 28.0475 - val_mae: 28.0475
# Epoch 23/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.8917 - mae: 26.8917 - val_loss: 27.4882 - val_mae: 27.4882
# Epoch 24/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.4023 - mae: 27.4023 - val_loss: 27.5260 - val_mae: 27.5260
# Epoch 25/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.0735 - mae: 27.0735 - val_loss: 27.4629 - val_mae: 27.4629
# Epoch 26/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.1537 - mae: 27.1537 - val_loss: 27.0676 - val_mae: 27.0676
# Epoch 27/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.7047 - mae: 26.7047 - val_loss: 28.4260 - val_mae: 28.4260
# Epoch 28/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.4577 - mae: 27.4577 - val_loss: 27.4314 - val_mae: 27.4314
# Epoch 29/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.9340 - mae: 26.9340 - val_loss: 26.6441 - val_mae: 26.6441
# Epoch 30/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.2255 - mae: 26.2255 - val_loss: 27.5914 - val_mae: 27.5914
# Epoch 31/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.0998 - mae: 27.0998 - val_loss: 27.2666 - val_mae: 27.2666
# Epoch 32/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.3183 - mae: 27.3183 - val_loss: 27.9195 - val_mae: 27.9195
# Epoch 33/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.7375 - mae: 26.7375 - val_loss: 26.4464 - val_mae: 26.4464
# Epoch 34/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.6103 - mae: 26.6103 - val_loss: 26.7710 - val_mae: 26.7710
# Epoch 35/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.5376 - mae: 26.5376 - val_loss: 28.6685 - val_mae: 28.6685
# Epoch 36/50
# 32/32 [==============================] - 0s 4ms/step - loss: 27.0012 - mae: 27.0012 - val_loss: 26.5748 - val_mae: 26.5748
# Epoch 37/50
# 32/32 [==============================] - 0s 5ms/step - loss: 25.7678 - mae: 25.7678 - val_loss: 26.3860 - val_mae: 26.3860
# Epoch 38/50
# 32/32 [==============================] - 0s 5ms/step - loss: 25.5629 - mae: 25.5629 - val_loss: 25.3977 - val_mae: 25.3977
# Epoch 39/50
# 32/32 [==============================] - 0s 4ms/step - loss: 25.8935 - mae: 25.8935 - val_loss: 26.0367 - val_mae: 26.0367
# Epoch 40/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.0677 - mae: 26.0677 - val_loss: 26.6268 - val_mae: 26.6268
# Epoch 41/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.8886 - mae: 26.8886 - val_loss: 26.4638 - val_mae: 26.4638
# Epoch 42/50
# 32/32 [==============================] - 0s 4ms/step - loss: 25.8403 - mae: 25.8403 - val_loss: 26.5055 - val_mae: 26.5055
# Epoch 43/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.2736 - mae: 26.2736 - val_loss: 26.4878 - val_mae: 26.4878
# Epoch 44/50
# 32/32 [==============================] - 0s 5ms/step - loss: 25.4068 - mae: 25.4068 - val_loss: 27.0261 - val_mae: 27.0261
# Epoch 45/50
# 32/32 [==============================] - 0s 4ms/step - loss: 25.1843 - mae: 25.1843 - val_loss: 27.2742 - val_mae: 27.2742
# Epoch 46/50
# 32/32 [==============================] - 0s 4ms/step - loss: 25.9047 - mae: 25.9047 - val_loss: 25.1356 - val_mae: 25.1356
# Epoch 47/50
# 32/32 [==============================] - 0s 4ms/step - loss: 24.6552 - mae: 24.6552 - val_loss: 25.1747 - val_mae: 25.1747
# Epoch 48/50
# 32/32 [==============================] - 0s 4ms/step - loss: 25.0530 - mae: 25.0530 - val_loss: 24.8620 - val_mae: 24.8620
# Epoch 49/50
# 32/32 [==============================] - 0s 4ms/step - loss: 24.3628 - mae: 24.3628 - val_loss: 24.3652 - val_mae: 24.3652
# Epoch 50/50
# 32/32 [==============================] - 0s 4ms/step - loss: 24.1074 - mae: 24.1074 - val_loss: 24.8069 - val_mae: 24.8069

# %%
#model2 - trying LeakyReLU to avoid dead neurons

# Split data into train and test sets
x_train2, x_test2, y_train2, y_test2 = train_test_split(xc, yc, test_size=0.6, random_state=42)

#define model
model2 = Sequential()
model2.add(Input(shape=(1,)))
#if I want to forced alpha to be 0.01
#model2.add(Dense(150,activation = keras.layers.LeakyReLU(alpha=0.01)))
#using default value: 0.3
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(150,activation = "LeakyReLU"))
model2.add(Dense(1))

#compile model
model2.compile(
   loss = 'MAE', optimizer = 'Adam', metrics=['mae']
)
model2.fit(x_train2, y_train2, epochs=50, batch_size=128, validation_data=(x_test2, y_test2))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 7ms/step - loss: 31.7743 - mae: 31.7743 - val_loss: 32.0775 - val_mae: 32.0775
# Epoch 2/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.7256 - mae: 31.7256 - val_loss: 32.0978 - val_mae: 32.0978
# Epoch 3/50
# 32/32 [==============================] - 0s 4ms/step - loss: 31.6623 - mae: 31.6623 - val_loss: 32.0830 - val_mae: 32.0830
# Epoch 4/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.6621 - mae: 31.6621 - val_loss: 31.9953 - val_mae: 31.9953
# Epoch 5/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.5950 - mae: 31.5950 - val_loss: 31.9681 - val_mae: 31.9681
# Epoch 6/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.4927 - mae: 31.4927 - val_loss: 31.7689 - val_mae: 31.7689
# Epoch 7/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.2590 - mae: 31.2590 - val_loss: 31.5198 - val_mae: 31.5198
# Epoch 8/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.8505 - mae: 31.8505 - val_loss: 31.8711 - val_mae: 31.8711
# Epoch 9/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.4948 - mae: 31.4948 - val_loss: 31.7653 - val_mae: 31.7653
# Epoch 10/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.3048 - mae: 31.3048 - val_loss: 31.6513 - val_mae: 31.6513
# Epoch 11/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.8686 - mae: 30.8686 - val_loss: 32.0382 - val_mae: 32.0382
# Epoch 12/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.0832 - mae: 31.0832 - val_loss: 30.9803 - val_mae: 30.9803
# Epoch 13/50
# 32/32 [==============================] - 0s 5ms/step - loss:
50
# 32/32 [==============================] - 0s 5ms/step - loss: 25.9079 - mae: 25.9079 - val_loss: 26.1040 - val_mae: 26.1040
# Epoch 46/50
# 32/32 [==============================] - 0s 5ms/step - loss: 26.4293 - mae: 26.4293 - val_loss: 28.6456 - val_mae: 28.6456
# Epoch 47/50
# 32/32 [==============================] - 0s 5ms/step - loss: 26.6722 - mae: 26.6722 - val_loss: 26.5577 - val_mae: 26.5577
# Epoch 48/50
# 32/32 [==============================] - 0s 5ms/step - loss: 25.9205 - mae: 25.9205 - val_loss: 26.4576 - val_mae: 26.4576
# Epoch 49/50
# 32/32 [==============================] - 0s 5ms/step - loss: 26.2572 - mae: 26.2572 - val_loss: 25.5921 - val_mae: 25.5921
# Epoch 50/50
# 32/32 [==============================] - 0s 5ms/step - loss: 25.1309 - mae: 25.1309 - val_loss: 27.5792 - val_mae: 27.5792

# %%
#model3 - trying PReLU due to varying characteristics and signal propagation

# Split data into train and test sets
x_train3, x_test3, y_train3, y_test3 = train_test_split(xc, yc, test_size=0.6, random_state=42)

#define model
model3 = Sequential()
model3.add(Input(shape=(1,)))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(150,activation = "ELU"))
model3.add(Dense(1))

#compile model
model3.compile(
   loss = 'MAE', optimizer = 'Adam', metrics=['mae']
)
model3.fit(x_train3, y_train3, epochs=50, batch_size=128, validation_data=(x_test3, y_test3))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 1s 7ms/step - loss: 31.5004 - mae: 31.5004 - val_loss: 31.6920 - val_mae: 31.6920
# Epoch 2/50
# 32/32 [==============================] - 0s 5ms/step - loss: 30.9589 - mae: 30.9589 - val_loss: 31.0113 - val_mae: 31.0113
# Epoch 3/50
# 32/32 [==============================] - 0s 5ms/step - loss: 29.7336 - mae: 29.7336 - val_loss: 29.7970 - val_mae: 29.7970
# Epoch 4/50
# 32/32 [==============================] - 0s 6ms/step - loss: 28.9396 - mae: 28.9396 - val_loss: 29.1041 - val_mae: 29.1041
# Epoch 5/50
# 32/32 [==============================] - 0s 5ms/step - loss: 28.0542 - mae: 28.0542 - val_loss: 28.1476 - val_mae: 28.1476
# Epoch 6/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.7621 - mae: 27.7621 - val_loss: 27.8633 - val_mae: 27.8633
# Epoch 7/50
# 32/32 [==============================] - 0s 6ms/step - loss: 27.0419 - mae: 27.0419 - val_loss: 26.4591 - val_mae: 26.4591
# Epoch 8/50
# 32/32 [==============================] - 0s 6ms/step - loss: 26.7672 - mae: 26.7672 - val_loss: 25.9331 - val_mae: 25.9331
# Epoch 9/50
# 32/32 [==============================] - 0s 6ms/step - loss: 26.0665 - mae: 26.0665 - val_loss: 29.3035 - val_mae: 29.3035
# Epoch 10/50
# 32/32 [==============================] - 0s 6ms/step - loss: 26.5019 - mae: 26.5019 - val_loss: 25.1405 - val_mae: 25.1405
# Epoch 11/50
# 32/32 [==============================] - 0s 6ms/step - loss: 25.6736 - mae: 25.6736 - val_loss: 25.7082 - val_mae: 25.7082
# Epoch 12/50
# 32/32 [==============================] - 0s 6ms/step - loss: 24.1363 - mae: 24.1363 - val_loss: 24.5587 - val_mae: 24.5587
# Epoch 13/50
# 32/32 [==============================] - 0s 6ms/step - loss: 25.3940 - mae: 25.3940 - val_loss: 23.5449 - val_mae: 23.5449
# Epoch 14/50
# 32/32 [==============================] - 0s 6ms/step - loss: 24.1081 - mae: 24.1081 - val_loss: 23.5170 - val_mae: 23.5170
# Epoch 15/50
# 32/32 [==============================] - 0s 5ms/step - loss: 22.8530 - mae: 22.8530 - val_loss: 25.5913 - val_mae: 25.5913
# Epoch 16/50
# 32/32 [==============================] - 0s 5ms/step - loss: 23.3073 - mae: 23.3073 - val_loss: 25.0064 - val_mae: 25.0064
# Epoch 17/50
# 32/32 [==============================] - 0s 6ms/step - loss:
# Epoch 41/50
# 32/32 [==============================] - 0s 5ms/step - loss: 18.0125 - mae: 18.0125 - val_loss: 20.3364 - val_mae: 20.3364
# Epoch 42/50
# 32/32 [==============================] - 0s 6ms/step - loss: 19.1589 - mae: 19.1589 - val_loss: 19.1366 - val_mae: 19.1366
# Epoch 43/50
# 32/32 [==============================] - 0s 6ms/step - loss: 18.2197 - mae: 18.2197 - val_loss: 19.2804 - val_mae: 19.2804
# Epoch 44/50
# 32/32 [==============================] - 0s 6ms/step - loss: 18.0798 - mae: 18.0798 - val_loss: 19.3906 - val_mae: 19.3906
# Epoch 45/50
# 32/32 [==============================] - 0s 8ms/step - loss: 16.9112 - mae: 16.9112 - val_loss: 19.1106 - val_mae: 19.1106
# Epoch 46/50
# 32/32 [==============================] - 0s 6ms/step - loss: 19.0148 - mae: 19.0148 - val_loss: 17.3850 - val_mae: 17.3850
# Epoch 47/50
# 32/32 [==============================] - 0s 6ms/step - loss: 18.2763 - mae: 18.2763 - val_loss: 18.9255 - val_mae: 18.9255
# Epoch 48/50
# 32/32 [==============================] - 0s 7ms/step - loss: 18.2458 - mae: 18.2458 - val_loss: 21.8205 - val_mae: 21.8205
# Epoch 49/50
# 32/32 [==============================] - 0s 6ms/step - loss: 18.2087 - mae: 18.2087 - val_loss: 18.0310 - val_mae: 18.0310
# Epoch 50/50
# 32/32 [==============================] - 0s 6ms/step - loss: 17.4780 - mae: 17.4780 - val_loss: 19.3810 - val_mae: 19.3810

# %% [markdown]
# #### Part 3 model evaluation
#
# In the cells below, eval your model with training data, test data ( with model.evaluate( ) ), and plot your predict result on the same plot with the plot of goal function.

# %%
import matplotlib.pyplot as plt

# Evaluate the model1 on training data
train_loss1 = model1.evaluate(x_train1, y_train1)
print("Training Loss1:", train_loss1)

# Evaluate the model on test data
#loss1, accuracy1 = model1.evaluate(x_test1, y_test1)   #accuracy is not used in this lab
test_loss1 = model1.evaluate(x_test1, y_test1)
print("Test Loss1:", test_loss1)

py1 = model1.predict(xc)

plt.plot(xc, py1)
plt.plot(xc, yc)
plt.title("Model1 Fit")
plt.show()

# Evaluate the model2 on training data
train_loss2 = model2.evaluate(x_train2, y_train2)
print("Training Loss2:", train_loss2)

# Evaluate the model on test data
test_loss2 = model2.evaluate(x_test2, y_test2)
print("Test Loss2:", test_loss2)

py2 = model2.predict(xc)

plt.plot(xc, py2)
plt.plot(xc, yc)
plt.title("Model2 Fit")
plt.show()

# Evaluate the model3 on training data
train_loss3 = model3.evaluate(x_train3, y_train3)
print("Training Loss3:", train_loss3)

# Evaluate the model on test data
test_loss3 = model3.evaluate(x_test3, y_test3)
print("Test Loss3:", test_loss3)

py3 = model3.predict(xc)

plt.plot(xc, py3)
plt.plot(xc, yc)
plt.title("Model3 Fit")
plt.show()
# Out:
#   1/125 [..............................] - ETA: 1s - loss: 23.0186 - mae: 23.0186
# 125/125 [==============================] - 0s 597us/step - loss: 24.2875 - mae: 24.2875
# Training Loss1: [24.287456512451172, 24.287456512451172]
# 188/188 [==============================] - 0s 615us/step - loss: 24.8069 - mae: 24.8069
# Test Loss1: [24.806947708129883, 24.806947708129883]
# 313/313 [==============================] - 0s 501us/step
# 125/125 [==============================] - 0s 552us/step - loss: 27.2893 - mae: 27.2893
# Training Loss2: [27.28932762145996, 27.28932762145996]
# 188/188 [==============================] - 0s 600us/step - loss: 27.5792 - mae: 27.5792
# Test Loss2: [27.579238891601562, 27.579238891601562]
# 313/313 [==============================] - 0s 507us/step
# 125/125 [==============================] - 0s 774us/step - loss: 19.1244 - mae: 19.1244
# Training Loss3: [19.124418258666992, 19.124418258666992]
# 188/188 [==============================] - 0s 714us/step - loss: 19.3810 - mae: 19.3810
# Test Loss3: [19.381011962890625, 19.381011962890625]
# 313/313 [==============================] - 0s 638us/step

# %% [markdown]
# #### Part 4 get model output and feedforward by yourself
#
# Recall how a Feedforward Neural Network gets its output. Now choose your model with highest accuracy, and call get_weights( ) to get its weights and bias.
# <br> Hint: bias and weights have different dimensions in most cases. Try to guess which index represent bias before you look it up on the internet.
#
# <br> Afterwards, choose 5 data from your training dataset, do all the necessary calculations (with program of course), and get the output of your model. Compare it to the model.predict( ) result.
# <br> They should be identical for the first several digitals, if not for all digits.

# %%
# to pick the model that has the highest accuracy, we need to choose the model with lowest loss.

# Get the model with the highest accuracy
best_model = model1                         # Assuming model1 has the highest accuracy initially
lowest_loss = test_loss1
print("model1 selected as best model")

if test_loss2 < lowest_loss:
    lowest_loss = test_loss2
    best_model = model2
    print("model2 selected as best model")

if test_loss3 < lowest_loss:
    lowest_loss = test_loss3
    best_model = model3
    print("model3 selected as best model")

# Get the weights and biases of the chosen model
weights = []
biases = []

for layer in best_model.layers:
    weights.append(layer.get_weights()[0])
    biases.append(layer.get_weights()[1])

# Choose 5 random data points from the training dataset
x_samples = x_train1[:5]
# Reshape x_samples to have dimensions (num_samples, num_features)
x_samples = np.reshape(x_samples, (x_samples.shape[0], 1))

# Compute the output of the model manually
for i, (w, b) in enumerate(zip(weights, biases)):
    x_samples = np.dot(x_samples, w) + b
    if i < len(weights) - 1:            # Apply activation function except for the last layer
        if (best_model == model1):
            x_samples = np.maximum(x_samples, 0)  # ReLU activation function
        if (best_model == model2):
            #x_samples = np.maximum(0.01 * x_samples, x_samples)        # LeakyReLU using alpha as 0.01
            #https://stackoverflow.com/questions/64735352/details-about-alpha-in-tf-nn-leaky-relu-features-alpha-0-2-name-none#:~:text=So%20Leaky%20ReLU%20substitutes%20zero,learning%20without%20reaching%20dead%20end.
            x_samples = np.maximum(0.3 * x_samples, x_samples) # LeakyReLU using default values
        if (best_model == model3):
            x_samples = np.where(x_samples >= 0, x_samples, 1 * (np.exp(x_samples) - 1))  # ELU activation function

# Print the manually computed output and the output obtained from model.predict()
print("Manually Computed Output (weights and bias):")
print(x_samples)

# Get the output of the model using model.predict() and printing it
predicted_output = best_model.predict(x_train1[:5])
print("\nOutput from model.predict():")
print(predicted_output)
# Out:
# model1 selected as best model
# model3 selected as best model
# Manually Computed Output (weights and bias):
# [[-36.0610723 ]
#  [-13.02648482]
#  [ 21.84367891]
#  [ 33.58749232]
#  [ 54.4730454 ]]
# 1/1 [==============================] - 0s 11ms/step
#
# Output from model.predict():
# [[-36.06107  ]
#  [-13.0264845]
#  [ 21.843676 ]
#  [ 33.587494 ]
#  [ 54.472965 ]]
